# %%
import pandas as pd
import numpy as np

# %%
models = pd.read_csv('models.csv', index_col=0)

# %%
models.head()
# Out:
#         account_name        inv_horizon  inv_obj_least_imp  inv_obj_most_imp  \
# 0         Jane Wells       2 to 5 Years                  0                 3
# 1       Madison Ryan  Less than 2 Years                  0                 1
# 2         Eric Smith       2 to 5 Years                  0                 3
# 3       Travis Smith          Immediate                  1                 3
# 4  Michelle Williams          Immediate                  0                 3
#
#    inv_obj_some_imp  inv_obj_very_imp  investment_amt liquidity_need  \
# 0                 0                 2          632860  Over 20 Years
# 1                 2                 4          251418       Lump Sum
# 2                 1                 2          223181  Over 20 Years
# 3                 2                 4          459374  6 to 10 Years
# 4                 1                 0          430662   2 to 5 Years
#
#    model_id                       model_name            primary_fin_need  \
# ...

# %%
products = pd.read_csv('equities.csv', index_col=0)

# %%
products.tail()
# Out:
#      Symbol                           Name     MarketCap             Sector  \
# 3577     ZS                  Zscaler, Inc.  7.604511e+09         Technology
# 3578   ZUMZ                    Zumiez Inc.  8.909743e+08  Consumer Services
# 3579   ZYNE  Zynerba Pharmaceuticals, Inc.  1.322287e+08        Health Care
# 3580   ZYXI                    Zynex, Inc.  3.500253e+08        Health Care
# 3581   ZNGA                     Zynga Inc.  6.309303e+09         Technology
#
#                                                Industry         L2  \
# 3577                                       EDP Services    Mid Cap
# 3578                     Clothing/Shoe/Accessory Stores  Small Cap
# 3579                              Major Pharmaceuticals  Micro Cap
# 3580  Biotechnology: Electromedical & Electrotherape...  Small Cap
# 3581                                       EDP Services    Mid Cap
#
#       close_price  risk_score  return_2019  return_2018  return_2017  \
# ...
